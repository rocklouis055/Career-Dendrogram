# %%
def after10(details):
  print("Hello {0} .\n We are happy to help you.".format(details["name"]))
  print("Lets begain the test")
  score={"science":0,"commerce":0,"arts":0,}
  score=test(0,0)

  print("Acording to your score,the possible path for you are :")
  if(score["biology"]+score["maths"]>=score["commerce"] and score["biology"]+score["maths"]>=score["arts"]):
    print("Best possible path for you is Science\n Other feasible options are Commerce and Arts")
    if(score["maths"]>=score["biology"]):
      print("In Science field,best possible path for you is Maths ")
      print("Specialized Jobs are :",path["science"]["btech"])
    else:
      print("In Science field,best possible path for you is Biology ")
      print("Specialized Jobs are :",path["science"]["mbbs"])
      print("Non-Specialized Jobs are :",path["commerce"],path["arts"])
    print("Other feasible Jobs are :",path["common"])
  elif(score["commerce"]>=score["arts"]):
    print("Best possible path for you is Commerce\n Other feasible option is Arts")
    print("Specialized Jobs are :",path["commerce"])
    print("Other feasible Jobs are :",path["common"])
  else:
    print("Best possible path for you is Arts")
    print("Specialized Jobs are :",path["arts"])
    print("Other feasible Jobs are :",path["common"])

# %%
def after12(details):
  print("Hello {}.\n We are happy to help you.".format(details["name"]))
  print("Looks like you came from field of {}".format(details["field"]))
  print("So we will be testing you against the question of the field {}".format(details["field"]))
  if(details["field"]=="science"):
    score=test(1,0)
  elif(details["field"]=="commerce"):
    score=test(1,1)
  elif(details["field"]=="arts"):
    score=test(1,2)
  print("Acording to your score,the possible path for you are :")
  if(details["field"]=="science"):
    if(score["btech"]>=score["mbbs"]):
      print("Best possible path for you is B.Tech")
      print("Specialized Jobs are :",path["science"]["btech"])
    else:
      print("Best possible path for you is M.B.B.S")
      print("Specialized Jobs are :",path["science"]["mbbs"])
    print("Other feasible Jobs are :",path["common"])
  elif(details["field"]=="commerce"):
    if(score["bca"]>=score["llb"]):
      print("Best possible path for you is B.Ca")
      print("Specialized Jobs are :",path["commerce"]["bca"])
    else:
      print("Best possible path for you is L.L.B")
      print("Specialized Jobs are :",path["commerce"]["llb"])
    print("Other feasible Jobs are :",path["common"])
  else:
    if(score["bfa"]>=score["ba"]):
      print("Best possible path for you is B.F.A")
      print("Specialized Jobs are :",path["arts"]["bfa"])
    else:
      print("Best possible path for you is B.A")

    print("Other feasible Jobs are :",path["common"])

# %%
path={"science":{"btech":["Data Scientist","Data Analyst"],
                "mbbs":"Doctor"},
      "commerce":{"llb":"Advocate",
                  "bca":"Auditor"},
      "arts":{"bfa":"Artist",
              "ba":"teacher"},
      "common":{"StartUp","Pilot","R.J","Researcher","Physician","Lecturer"}
      }

# %%
def test(a,b):
  score={}
  sumbtech=0
  if(a==0):
    sum=0
    print("1.The largest cell is ________________\n(A) Nerve Cell\n(B) Ovum\n(C) The egg of an Ostrich\n(D) None of the above")
    n=input()
    if(n=="c"):
      sum=sum+1
    print("2. A proton donor is a chemical that\nA) protongenic\nB) protophilic\nC) amphoteric\nD) amphiprotic")
    n=input()
    if(n=="a"):
      sum=sum+1

    print("3. Cinnabar is used to extract which metal?\nA) Zinc\nB) Copper\nC) Iron\nD) Mercury")
    n=input()
    if(n=="d"):
      sum=sum+1
    score["biology"]=sum
    sumM=0
    print("1. In ∆ ABC, right-angled at B, AB = 24 cm, BC = 7 cm. The value of tan C is: \nA 12/7 B 24/7\nC 20/7\nD 7/24")
    n=input()
    if(n=="b"):
      sumM=sumM+1

    print("2. If cos X = ⅔ then tan X is equal to:\nA 5/2\nB √(5/2)\nC √5/2\nD 2/√5")
    n=input()
    if(n=="c"):
      sumM=sumM+1

    print("3. tan 30°/(1 + tan230°) =\nA sin 60°\nB cos 60°\nC tan 60°\nD sin 30°")
    n=input()
    if(n=="a"):
      sumM=sumM+1
    score["maths"]=sumM
    sumC=0
    print("1 Rishav takes a loan of Rs 10000 from a bank for a period of 1 year. The rate of interest is 10% per annum. Find the interest and the amount he has to pay at the end of a year.")
    print("A 11000")
    print("B 64566")
    print("C 50000")
  
    n=input()
    if(n=="a"):
      sumC=sumC+1

    print("2 Mohit pays Rs 9000 as an amount on the sum of Rs 7000 that he had borrowed for 2 years. Find the rate of interest.")
    print(" A 12.7 %")
    print(" B 34.9 %")
    print(" C 14.29 %")
    n=input()
    if(n=="c"):
      sumC=sumC+1

    print("3 The mode and mean is given by 7 and 8, respectively. Then the median is:")
    print(" A 1/13")
    print(" B 13/3")
    print(" C 23/3")
    print(" D 33")
    n=input()
    if(n=="c"):
      sumC=sumC+1
    score["commerce"]=sumC
    sumA=0
    print("1 In which year Sri Lanka emerged as an independent country?")
    print("A 1947\nB 1948\nC 1949\nD 1950")
    n=input()
    if(n=="b"):
      sumA=sumA+1
    print("2 In a good democratic government:")
    print("A Due respect is not given to diverse groups\nB Due respect is given to ministers only\nC Due respect is given to diverse groups and views\nD None of the above")
    n=input()
    if(n=="c"):
      sumA=sumA+1

    print("3 Giuseppe Mazzini founded the secret underground society named ‘Young Europe’ in ")
    print("A Marseilles\nB Berne\n C Vienna\n D Brussels")
    n=input()
    if(n=="b"):
      sumA=sumA+1
    score["arts"]=sumA
  elif(a==1):
    if(b==0):
      print("If length of pendulum is increased by 2%. The time period will\n(A) increases by 1%\n(B) decreases by 1%\n(C) increases by 2%\n(D) decreases by 2%")
      n=input()
      if(n=="a"):
        sumbtech+=1
      print("A trolley car slides down a smooth inclined plane of angle of inclination θ. If a body is suspended from the roof of the trolley car by an inextensible string of length l, the corresponding tension in the string will be\n(A) mg\n(B) mg cosθ\n(C) mg sinθ\n(D) None of these")
      n=input()
      if(n=="b"):
        sumbtech+=1
      print("A man can swim at a speed of 5 km/h w.r.t. water. He wants to cross a 1.5 km wide river flowing at 3 km/h. He keeps himself always at an angle of 60° with the flow direction while swimming. The time taken by him to cross the river will be\n(A) 0.25 hr.\n(B) 0.35 hr.\n(C) 0.45 hr.\n(D) 0.55 hr.")
      n=input()
      if(n=="b"):
        sumbtech+=1
      score["btech"]=sumbtech
      sumMBBS=0
      print("1 Transplanted graft may be rejected due to: \nA cell-mediated immune response\nB humoral immune response\nC innate immune response\nD passive response")
      n=input()
      if(n=="a"):
        sumMBBS=sumMBBS+1
      print("2 The class of antibodies, which can cross placenta is\nA IgD\nB IgA\nC IgG\nD IGM")
      n=input()
      if(n=="c"):
        sumMBBS=sumMBBS+1
      print("3 Antibodies are \nA prostaglandins\nB steroids\nC lipoproteins\n D glycoproteins")
      n=input()
      if(n=="c"):
        sumMBBS=sumMBBS+1
      score["mbbs"]=sumMBBS
    elif(b==1):
      sumbca=0
      print("The ledger column that links the entry with the journal is called as\n(a) J.F column\n(b) L.F column\n(c) Credit column\n(d) Debit column")
      n=input()
      if(n=="a"):
        sumbca+=1
      print("The concept of Financial management is\nA) Profit maximization\nB) All features of obtaining and using financial resources for company operations\nC) Organization of funds\nD) Effective Management of every company")
      n=input()
      if(n=="b"):
        sumbca+=1
      print("GST is a consumption of goods and service tax based on.\nA) Development\nB) Dividend\nC) Duration\nD) Destination")
      n=input()
      if(n=="d"):
        sumbca+=1
      score["bca"]=sumbca
      print(" Clause (4) of Article 15 has been added to the Constitution by\n(A) The Constitution First Amendment Act.\n(B) The Constitution Second Amendment Act\n(C) The Constitution Fourth Amendment Act.\n(D) The Constitution Sixth Amendment Act.")
      n=input()
      sumlaw=0
      if(n=="a"):
        sumlaw+=1
      print("In India sovereignty lies with\n(A) The Constitution\n(B) The Supreme Court\n(C) The Parliament\n(D) The People")
      n=input()
      if(n=="d"):
        sumlaw+=1
      print("The State shall endeavour to secure for the citizens a Uniform Civil Code throughout the territory of India as per\n(A) Article 40\n(B) Article 43\n(C) Article 44\n(D) Article 48")
      n=input()
      if(n=="c"):
        sumlaw+=1
      score["llb"]=sumlaw
    else:
      sumBFA=0
      print("1 In how many layers is oil paint applied to a surface?\nA 3\nB 4\nC 2\nD 1")
      n=input()
      if(n=="a"):
        sumBFA=sumBFA+1
      print("2 Anticorrosive paint is _____ in colour\nA Blue\nB White\nC Black\nD Yellow")
      n=input()
      if(n=="c"):
        sumBFA=sumBFA+1
      print("3 In which of the below, it is not necessary to remove existing paint to apply a new one?\n A Aluminium paints\nB Cement paints\nC Oil paints\nD Enamel paints")
      n=input()
      if(n=="b"):
        sumBFA=sumBFA+1

      sumBA=0
      print("1 Which of the following best represents the concept of Net Domestic Product (NDP)?\nAGDP - Income from abroad\nB GDP + Income from abroad\n CGNP - Depreciation\nD GDP - Depreciation")
      n=input()
      if(n=="d"):
        sumBA=sumBA+1
      print("2 In which city is the head office of the Insurance Regulatory and Development Authority of India (IRDAI) situated?\nA Shimla\nB Kolkata\nC Chandigarh\nD Hyderabad")
      n=input()
      if(n=="d"):
        sumBA=sumBA+1

      print("3 Macro economics is also called the\nA Theory of money\nB Theory of national income\nCTheory of income\nD Theory of inflation")
      n=input()
      if(n=="c"):
        sumBA=sumBA+1
      score["bfa"]=sumBFA
      score["ba"]=sumBA

  return(score)

# %%
detail={}
detail["name"]=input("Enter your name :")
n=int(input("Enter your req :\n1.After 10th\n2.After 12\n"))
if n==1:
  after10(detail)
else:
  n=int(input("Enter your field :\n1.Science\n2.Commerce\n3.Arts\n"))
  if n==1:
    detail["field"]="science"
  elif n==2:
    detail["field"]="commerce"
  else:
    detail["field"]="arts"
  after12(detail)
# Out:
# Enter your name :louise
# Enter your req :
# 1.After 10th
# 2.After 12
# 2
# Enter your field :
# 1.Science
# 2.Commerce
# 3.Arts
# 3
# Hello louise.
#  We are happy to help you.
# Looks like you came from field of arts
# So we will be testing you against the question of the field arts
# 1 In how many layers is oil paint applied to a surface?
# A 3
# B 4
# C 2
# D 1
# a
# 2 Anticorrosive paint is _____ in colour
# A Blue
# B White
# C Black
# D Yellow
# a
# a
# 3 In which of the below, it is not necessary to remove existing paint to apply a new one?
#  A Aluminium paints
# B Cement paints
# C Oil paints
# D Enamel paints
# 1 Which of the following best represents the concept of Net Domestic Product (NDP)?
# AGDP - Income from abroad
# B GDP + Income from abroad
#  CGNP - Depreciation
# D GDP - Depreciation
# a
# 2 In which city is the head office of the Insurance Regulatory and Development Authority of India (IRDAI) situated?
# A Shimla
# B Kolkata
# C Chandigarh
# D Hyderabad
# a
# ...
